-- %% [markdown]
-- # [dbo].[accesorios]

-- %%
USE [Optica]
GO

-- %%
/****** Object:  Table [dbo].[accesorios]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[accesorios](
	[id_accesorio] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [date] NOT NULL,
	[nombre_accesorio] [nvarchar](max) NOT NULL,
	[precio_accesorio] [float] NOT NULL,
	[cantidad_accesorios] [int] NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_accesorios] PRIMARY KEY CLUSTERED 
(
	[id_accesorio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[administrador]

-- %%
/****** Object:  Table [dbo].[administrador]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[administrador](
	[id_admin] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NOT NULL,
	[a_paterno] [nvarchar](50) NOT NULL,
	[a_materno] [nvarchar](50) NOT NULL,
	[edad] [int] NOT NULL,
	[sexo] [nvarchar](max) NOT NULL,
	[correo_electronico] [nvarchar](50) NOT NULL,
	[nombre_usuario] [nvarchar](50) NOT NULL,
	[contrasenia] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_administrador_1] PRIMARY KEY CLUSTERED 
(
	[id_admin] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[armazones]

-- %%
/****** Object:  Table [dbo].[armazones]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[armazones](
	[id_armazon] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [date] NOT NULL,
	[marca_armazon] [nvarchar](max) NOT NULL,
	[modelo_armazon] [nvarchar](max) NOT NULL,
	[material_armazon] [nvarchar](max) NOT NULL,
	[precio] [float] NOT NULL,
	[cantidad_armazones] [int] NOT NULL,
	[tipo_armazon] [nvarchar](max) NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_armazones] PRIMARY KEY CLUSTERED 
(
	[id_armazon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[clientes]

-- %%
/****** Object:  Table [dbo].[clientes]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[clientes](
	[id_cliente] [int] IDENTITY(1,1) NOT NULL,
	[fecha_alta] [date] NOT NULL,
	[nombre_cliente] [nvarchar](max) NOT NULL,
	[apellido_p] [nvarchar](max) NOT NULL,
	[apellido_m] [nvarchar](max) NOT NULL,
	[edad] [int] NOT NULL,
	[sexo] [nvarchar](50) NOT NULL,
	[ocupacion_cliente] [nvarchar](max) NOT NULL,
	[tipo_cliente] [nvarchar](50) NOT NULL,
	[telefono] [nvarchar](50) NOT NULL,
	[diabetico] [nvarchar](50) NOT NULL,
	[hipertenso] [nvarchar](50) NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_clientes] PRIMARY KEY CLUSTERED 
(
	[id_cliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[graduacion_cliente]

-- %%
/****** Object:  Table [dbo].[graduacion_cliente]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[graduacion_cliente](
	[id_graduacion] [int] IDENTITY(1,1) NOT NULL,
	[nombre_paciente] [nvarchar](max) NOT NULL,
	[fecha_registro] [nvarchar](max) NOT NULL,
	[alcance_OD] [nvarchar](max) NOT NULL,
	[alcance_OI] [nvarchar](max) NOT NULL,
	[esfera] [nvarchar](max) NOT NULL,
	[cilindro] [nvarchar](max) NOT NULL,
	[eje] [nvarchar](max) NOT NULL,
	[adición] [nvarchar](max) NOT NULL,
	[observaciones] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_graduacion_cliente] PRIMARY KEY CLUSTERED 
(
	[id_graduacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lc_color]

-- %%
/****** Object:  Table [dbo].[lc_color]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lc_color](
	[id_lentecolor] [int] IDENTITY(1,1) NOT NULL,
	[fecha_agregado] [date] NOT NULL,
	[graduacion_lcc] [nvarchar](max) NOT NULL,
	[color_lcc] [nvarchar](max) NOT NULL,
	[marca_lcc] [nvarchar](max) NOT NULL,
	[precio_lcc] [float] NOT NULL,
	[existentes_lcc] [int] NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_lc_color] PRIMARY KEY CLUSTERED 
(
	[id_lentecolor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lc_esferico]

-- %%
/****** Object:  Table [dbo].[lc_esferico]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lc_esferico](
	[id_lenteesf] [int] IDENTITY(1,1) NOT NULL,
	[fecha_agregado] [nvarchar](max) NOT NULL,
	[graduacion_lente] [nvarchar](max) NOT NULL,
	[marca_lce] [nvarchar](max) NOT NULL,
	[precio_lce] [float] NOT NULL,
	[existentes_lce] [int] NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_lc_esferico] PRIMARY KEY CLUSTERED 
(
	[id_lenteesf] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lc_torico]

-- %%
/****** Object:  Table [dbo].[lc_torico]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lc_torico](
	[id_lente] [int] IDENTITY(1,1) NOT NULL,
	[fecha_lct] [date] NOT NULL,
	[esfera_lct] [nvarchar](50) NOT NULL,
	[cilindro_lct] [nvarchar](50) NOT NULL,
	[eje_lct] [nvarchar](50) NOT NULL,
	[marca_lct] [nvarchar](max) NOT NULL,
	[precio] [float] NOT NULL,
	[cant_existente] [int] NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_lc_torico] PRIMARY KEY CLUSTERED 
(
	[id_lente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[micas]

-- %%
/****** Object:  Table [dbo].[micas]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[micas](
	[id_mica] [int] IDENTITY(1,1) NOT NULL,
	[material_mica] [nvarchar](max) NOT NULL,
	[tipo_mica] [nvarchar](max) NOT NULL,
	[tipo_material] [nvarchar](max) NOT NULL,
	[trat_mica] [nvarchar](max) NOT NULL,
	[precio] [float] NOT NULL,
	[responsable] [nvarchar](max) NOT NULL,
	[fecha] [date] NOT NULL,
 CONSTRAINT [PK_micas] PRIMARY KEY CLUSTERED 
(
	[id_mica] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vendedores]

-- %%
/****** Object:  Table [dbo].[vendedores]    Script Date: 30/10/2020 07:47:29 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vendedores](
	[id_usuario] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NOT NULL,
	[a_paterno] [nvarchar](50) NOT NULL,
	[a_materno] [nvarchar](50) NOT NULL,
	[edad] [int] NOT NULL,
	[sexo] [nvarchar](50) NOT NULL,
	[correo_electronico] [nvarchar](50) NOT NULL,
	[nombre_usuario] [nvarchar](50) NOT NULL,
	[contrasenia] [nvarchar](50) NOT NULL,
	[admin_responsable] [varchar](max) NOT NULL,
	[fecha_vendedor] [date] NOT NULL,
 CONSTRAINT [PK_vendedores] PRIMARY KEY CLUSTERED 
(
	[id_usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
